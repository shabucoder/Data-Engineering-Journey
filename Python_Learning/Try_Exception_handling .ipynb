# %% [markdown]
# **TRY AND EXCEPTION CONCEPT**
#
# `SYNTAX`
#
# Try:
#
# Print('Code that might cause an error')
#
# Exception:
#
# Print('code that runs if error occurs in the try block')

# %%
## simple Example 

try:
    number = int(input('Enter the number'))
except:
    print('You Enter wrong input data type,  Please only enter the interger type')
# Out:
# You Enter wrong input data type,  Please only enter the interger type
