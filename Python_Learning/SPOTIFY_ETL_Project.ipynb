# %%
# !pip install spotipy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 394.9/394.9 kB 8.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
from spotipy.oauth2 import SpotifyClientCredentials

client_credentials_manager = SpotifyClientCredentials(client_id="54403b3d57dc4ee9a3511182b44c5441",client_secret= "dbfa18d3a6b5430abb03dca47af93f6f")

sp = spotipy.Spotify(client_credentials_manager=client_credentials_manager)

data1 = sp.playlist_tracks('https://open.spotify.com/playlist/6VOedaf3eNWDOVpa9Qdlvg?si=Mv3YpzauSRmCaSkXp7H1vQ')
# Out:
# HTTP Error for GET to https://api.spotify.com/v1/playlists/6VOedaf3eNWDOVpa9Qdlvg/tracks with Params: {'limit': 100, 'offset': 0, 'fields': None, 'market': None, 'additional_types': 'track'} returned 403 due to Check settings on developer.spotify.com/dashboard, the user may not be registered.
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/spotipy/client.py:271, in Spotify._internal_call(self, method, url, payload, params)
#     266 response = self._session.request(
#     267     method, url, headers=headers, proxies=self.proxies,
#     268     timeout=self.requests_timeout, **args
#     269 )
# --> 271 response.raise_for_status()
#     272 results = response.json()
#
# File /opt/anaconda3/lib/python3.11/site-packages/requests/models.py:1021, in Response.raise_for_status(self)
#    1020 if http_error_msg:
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import os

# Delete old cache
if os.path.exists('.cache'):
    os.remove('.cache')

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id="54403b3d57dc4ee9a3511182b44c5441",
    client_secret="dbfa18d3a6b5430abb03dca47af93f6f",
    redirect_uri="http://127.0.0.1:8888/callback",
    scope="playlist-read-private playlist-read-collaborative"
))

data = sp.playlist_items('6VOedaf3eNWDOVpa9Qdlvg')
print(data)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[44], line 16
#       7     os.remove('.cache')
#       9 sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
#      10     client_id="54403b3d57dc4ee9a3511182b44c5441",
#      11     client_secret="dbfa18d3a6b5430abb03dca47af93f6f",
#      12     redirect_uri="http://127.0.0.1:8888/callback",
#      13     scope="playlist-read-private playlist-read-collaborative"
#      14 ))
# ---> 16 data = sp.playlist_items('6VOedaf3eNWDOVpa9Qdlvg')
#      17 print(data)
#
# File /opt/anaconda3/lib/python3.11/site-packages/spotipy/client.py:732, in Spotify.playlist_items(self, playlist_id, fields, limit, offset, market, additional_types)
#     720 """ Get full details of the tracks and episodes of a playlist.
#     721
#     722     Parameters:
#    (...)
#     729                              valid types are: track and episode
# ...

# %%
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import os

if os.path.exists('.cache'):
    os.remove('.cache')

sp = spotipy.Spotify(auth_manager=SpotifyOAuth(
    client_id="54403b3d57dc4ee9a3511182b44c5441",
    client_secret="dbfa18d3a6b5430abb03dca47af93f6f",
    redirect_uri="http://127.0.0.1:7777/callback",
    scope="playlist-read-private playlist-read-collaborative"
))

data = sp.playlist_items('6VOedaf3eNWDOVpa9Qdlvg')
print(data)
# Out:
# {'href': 'https://api.spotify.com/v1/playlists/6VOedaf3eNWDOVpa9Qdlvg/tracks?offset=0&limit=100&additional_types=track', 'items': [{'added_at': '2025-05-10T16:34:06Z', 'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/31rzz7jr6t3e3mqgitwppkmfg2ve'}, 'href': 'https://api.spotify.com/v1/users/31rzz7jr6t3e3mqgitwppkmfg2ve', 'id': '31rzz7jr6t3e3mqgitwppkmfg2ve', 'type': 'user', 'uri': 'spotify:user:31rzz7jr6t3e3mqgitwppkmfg2ve'}, 'is_local': False, 'primary_color': None, 'track': {'preview_url': None, 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 
# ...
